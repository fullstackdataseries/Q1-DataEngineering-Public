# %% [markdown]
# # Create Data Model
#
# The end of this file will have a data model with 2 fact tables and 3 dim tables! and we will talk about business use cases for them

# %% [markdown]
# ## See the slides from today
# - https://www.canva.com/design/DAF6qdYt1uI/EDC80b79R8FiUZ7HNi6_ig/view?utm_content=DAF6qdYt1uI&utm_campaign=designshare&utm_medium=link&utm_source=editor

# %%
import pandas as pd
import duckdb
import pathlib
import os

# Define Data Path
try:
    workshop_root_dir = pathlib.Path(__file__).absolute().parent
except:
    workshop_root_dir = pathlib.Path(pathlib.Path().absolute().parent)

if os.path.exists(workshop_root_dir / "data/transactions_multithreaded.json"):
    os.chdir(workshop_root_dir)
    
data_path = pathlib.Path(workshop_root_dir, 'data')

# Read In Data
json_data = duckdb.sql(f"SELECT * FROM read_json_auto('{data_path}/transactions_multithreaded.json')").fetchdf()

# %%
# Create Connection to load data into DB
con = duckdb.connect('duckdb.db', read_only=False)

# Load into PyRelation
relation = con.from_df(json_data)
# type(relation) # duckdb.PyRelation

# Create Schema for Landing Zone and Load data into Landing Zone
con.execute("""CREATE SCHEMA IF NOT EXISTS landing""")
con.execute("""CREATE TABLE IF NOT EXISTS landing.transactions AS SELECT * FROM relation""")

# %%
# Display as pandas df
con.execute("""SELECT * FROM landing.transactions""").fetchdf()
# Out:
#                 EventType            Timestamp  TransactionID  UserID  \
# 0     TransactionComplete  2020-06-13T00:00:00            191   43412
# 1     TransactionComplete  2018-07-13T00:00:00            137   21084
# 2     TransactionComplete  2016-05-30T00:00:00            300   31881
# 3     TransactionComplete  2017-08-04T00:00:00            227   36278
# 4     TransactionComplete  2016-05-04T00:00:00            336   28484
# ...                   ...                  ...            ...     ...
# 9995  TransactionComplete  2018-01-06T00:00:00           9996   63216
# 9996  TransactionComplete  2016-06-24T00:00:00           9997   82711
# 9997  TransactionComplete  2023-03-22T00:00:00           9998   88952
# 9998  TransactionComplete  2021-08-03T00:00:00           9999   97961
# 9999  TransactionComplete  2020-03-06T00:00:00          10000   15231
#
#                                  SessionID  TotalAmount  TaxAmount  \
# 0     36e4dab3-e6a6-4536-a69d-0a4257279869       605.38      39.07
# 1     ce47af78-2cd8-4b06-9da2-389b0400137a       229.18      14.66
# 2     98b20530-8c67-4e8d-97c2-39239055a7b9       253.00      15.80
# 3     9d77102e-cf54-4d3d-bb4c-e297095dafe9       214.83      13.81
# 4     b90cbe5e-2a19-4941-998d-a0b0760a80c1       461.68      30.05
# ...                                    ...          ...        ...
# 9995  edb7dccc-12cc-45e2-b264-3d2758ab7dba       650.22      42.03
# 9996  c59df868-a6cb-40fe-9da7-0dd947a5546d       619.88      40.44
# 9997  3bd46660-0be3-40db-a0ac-79acff0568de       120.18       7.66
# 9998  4ba5276b-84e7-4777-ac41-d855d5e85020       453.68      29.13
# 9999  cba7d390-3d52-4367-ba0c-b132e86057b4       266.50      17.00
#
#       ShippingAmount  Discounts  \
# 0              16.87       8.76
# 1              12.60       7.57
# 2              18.18       6.73
# 3               9.55       5.85
# 4               5.86       3.51
# ...              ...        ...
# 9995           17.18       9.36
# 9996            6.53       4.86
# 9997            9.17       6.14
# 9998           17.43       8.99
# 9999           12.68       6.05
#
#                                                Products PaymentType  \
# 0     [{'ProductID': 'Product_5', 'Quantity': 3, 'Pr...        Visa
# 1     [{'ProductID': 'Product_8', 'Quantity': 1, 'Pr...      PayPal
# 2     [{'ProductID': 'Product_8', 'Quantity': 2, 'Pr...      PayPal
# 3     [{'ProductID': 'Product_4', 'Quantity': 2, 'Pr...        Amex
# 4     [{'ProductID': 'Product_3', 'Quantity': 1, 'Pr...        Amex
# ...                                                 ...         ...
# 9995  [{'ProductID': 'Product_10', 'Quantity': 3, 'P...  MasterCard
# 9996  [{'ProductID': 'Product_5', 'Quantity': 3, 'Pr...        Amex
# 9997  [{'ProductID': 'Product_2', 'Quantity': 1, 'Pr...        Visa
# 9998  [{'ProductID': 'Product_7', 'Quantity': 1, 'Pr...        Amex
# 9999  [{'ProductID': 'Product_9', 'Quantity': 1, 'Pr...  MasterCard
#
#                                         ShippingAddress  \
# 0     993 Vance Expressway Suite 136\nNancystad, TN ...
# 1     0327 Richard Valley Apt. 051\nJonesborough, MA...
# 2     15402 Ayers Extensions Apt. 914\nNorth Jonatha...
# 3               54379 Wood Pine\nNorth Justin, ME 65095
# 4           87343 Ramirez Hills\nSouth Alison, OH 82680
# ...                                                 ...
# 9995        91445 Brian Spring\nKathleenhaven, AL 87960
# 9996     207 Hicks Bridge Apt. 085\nJamesstad, AZ 88710
# 9997            32859 Ryan Village\nKaylafort, CO 93184
# 9998                   Unit 3130 Box 2918\nDPO AP 83961
# 9999                           USS Morris\nFPO AP 23236
#
#                                          BillingAddress
# 0     058 Christopher Trail Apt. 870\nAdamsbury, IL ...
# 1               0867 Cynthia Lock\nLake Karen, NH 98346
# 2                   701 Pena Plaza\nEast Juan, AZ 10337
# 3     3059 Bullock Knolls\nSouth Christinahaven, SD ...
# 4            732 Joseph River\nHopkinsborough, SD 53819
# ...                                                 ...
# 9995           80262 Calvin Knoll\nNorth Lisa, NJ 92576
# 9996                         USNS Wallace\nFPO AE 25477
# 9997    658 Harris Brooks Apt. 276\nWest John, OK 89487
# 9998  31778 Powers Ford Suite 256\nEast Amytown, NE ...
# 9999   37579 Brian Cove Suite 116\nTuckerfurt, AS 92926
#
# [10000 rows x 13 columns]

# %%
 con.execute("""SELECT * FROM landing.transactions""").fetchdf()
# Out:
#                 EventType            Timestamp  TransactionID  UserID  \
# 0     TransactionComplete  2020-06-13T00:00:00            191   43412
# 1     TransactionComplete  2018-07-13T00:00:00            137   21084
# 2     TransactionComplete  2016-05-30T00:00:00            300   31881
# 3     TransactionComplete  2017-08-04T00:00:00            227   36278
# 4     TransactionComplete  2016-05-04T00:00:00            336   28484
# ...                   ...                  ...            ...     ...
# 9995  TransactionComplete  2018-01-06T00:00:00           9996   63216
# 9996  TransactionComplete  2016-06-24T00:00:00           9997   82711
# 9997  TransactionComplete  2023-03-22T00:00:00           9998   88952
# 9998  TransactionComplete  2021-08-03T00:00:00           9999   97961
# 9999  TransactionComplete  2020-03-06T00:00:00          10000   15231
#
#                                  SessionID  TotalAmount  TaxAmount  \
# 0     36e4dab3-e6a6-4536-a69d-0a4257279869       605.38      39.07
# 1     ce47af78-2cd8-4b06-9da2-389b0400137a       229.18      14.66
# 2     98b20530-8c67-4e8d-97c2-39239055a7b9       253.00      15.80
# 3     9d77102e-cf54-4d3d-bb4c-e297095dafe9       214.83      13.81
# 4     b90cbe5e-2a19-4941-998d-a0b0760a80c1       461.68      30.05
# ...                                    ...          ...        ...
# 9995  edb7dccc-12cc-45e2-b264-3d2758ab7dba       650.22      42.03
# 9996  c59df868-a6cb-40fe-9da7-0dd947a5546d       619.88      40.44
# 9997  3bd46660-0be3-40db-a0ac-79acff0568de       120.18       7.66
# 9998  4ba5276b-84e7-4777-ac41-d855d5e85020       453.68      29.13
# 9999  cba7d390-3d52-4367-ba0c-b132e86057b4       266.50      17.00
#
#       ShippingAmount  Discounts  \
# 0              16.87       8.76
# 1              12.60       7.57
# 2              18.18       6.73
# 3               9.55       5.85
# 4               5.86       3.51
# ...              ...        ...
# 9995           17.18       9.36
# 9996            6.53       4.86
# 9997            9.17       6.14
# 9998           17.43       8.99
# 9999           12.68       6.05
#
#                                                Products PaymentType  \
# 0     [{'ProductID': 'Product_5', 'Quantity': 3, 'Pr...        Visa
# 1     [{'ProductID': 'Product_8', 'Quantity': 1, 'Pr...      PayPal
# 2     [{'ProductID': 'Product_8', 'Quantity': 2, 'Pr...      PayPal
# 3     [{'ProductID': 'Product_4', 'Quantity': 2, 'Pr...        Amex
# 4     [{'ProductID': 'Product_3', 'Quantity': 1, 'Pr...        Amex
# ...                                                 ...         ...
# 9995  [{'ProductID': 'Product_10', 'Quantity': 3, 'P...  MasterCard
# 9996  [{'ProductID': 'Product_5', 'Quantity': 3, 'Pr...        Amex
# 9997  [{'ProductID': 'Product_2', 'Quantity': 1, 'Pr...        Visa
# 9998  [{'ProductID': 'Product_7', 'Quantity': 1, 'Pr...        Amex
# 9999  [{'ProductID': 'Product_9', 'Quantity': 1, 'Pr...  MasterCard
#
#                                         ShippingAddress  \
# 0     993 Vance Expressway Suite 136\nNancystad, TN ...
# 1     0327 Richard Valley Apt. 051\nJonesborough, MA...
# 2     15402 Ayers Extensions Apt. 914\nNorth Jonatha...
# 3               54379 Wood Pine\nNorth Justin, ME 65095
# 4           87343 Ramirez Hills\nSouth Alison, OH 82680
# ...                                                 ...
# 9995        91445 Brian Spring\nKathleenhaven, AL 87960
# 9996     207 Hicks Bridge Apt. 085\nJamesstad, AZ 88710
# 9997            32859 Ryan Village\nKaylafort, CO 93184
# 9998                   Unit 3130 Box 2918\nDPO AP 83961
# 9999                           USS Morris\nFPO AP 23236
#
#                                          BillingAddress
# 0     058 Christopher Trail Apt. 870\nAdamsbury, IL ...
# 1               0867 Cynthia Lock\nLake Karen, NH 98346
# 2                   701 Pena Plaza\nEast Juan, AZ 10337
# 3     3059 Bullock Knolls\nSouth Christinahaven, SD ...
# 4            732 Joseph River\nHopkinsborough, SD 53819
# ...                                                 ...
# 9995           80262 Calvin Knoll\nNorth Lisa, NJ 92576
# 9996                         USNS Wallace\nFPO AE 25477
# 9997    658 Harris Brooks Apt. 276\nWest John, OK 89487
# 9998  31778 Powers Ford Suite 256\nEast Amytown, NE ...
# 9999   37579 Brian Cove Suite 116\nTuckerfurt, AS 92926
#
# [10000 rows x 13 columns]

# %%
con.execute("""SELECT Products FROM landing.transactions LIMIT 10000""").fetchdf()
# Out:
#                                                Products
# 0     [{'ProductID': 'Product_5', 'Quantity': 3, 'Pr...
# 1     [{'ProductID': 'Product_8', 'Quantity': 1, 'Pr...
# 2     [{'ProductID': 'Product_8', 'Quantity': 2, 'Pr...
# 3     [{'ProductID': 'Product_4', 'Quantity': 2, 'Pr...
# 4     [{'ProductID': 'Product_3', 'Quantity': 1, 'Pr...
# ...                                                 ...
# 9995  [{'ProductID': 'Product_10', 'Quantity': 3, 'P...
# 9996  [{'ProductID': 'Product_5', 'Quantity': 3, 'Pr...
# 9997  [{'ProductID': 'Product_2', 'Quantity': 1, 'Pr...
# 9998  [{'ProductID': 'Product_7', 'Quantity': 1, 'Pr...
# 9999  [{'ProductID': 'Product_9', 'Quantity': 1, 'Pr...
#
# [10000 rows x 1 columns]

# %%
## Unpack LIST(STRUCT[]) type in the DF
unpacked_products_df = con.execute("""
            
            -- Filter to first 20k rows
            WITH filter AS (
            SELECT *, ROW_NUMBER() OVER() AS row_num
            FROM landing.transactions
            ),
            
            -- Products col is of type LIST, need to extract (1-indexed)
            extract_list AS (
                SELECT *,
                    unnest(Products) AS Products_Extract
                FROM filter
                        )

            -- Now we can unpack the STRUCT type
            SELECT *,
                Products_Extract.*
            FROM extract_list""").fetch_arrow_table()

# %%
# Check it
unpacked_products_df.to_pandas().iloc[:, -5:]
# Out:
#        row_num                                   Products_Extract   ProductID  \
# 0            1  {'ProductID': 'Product_5', 'Quantity': 3, 'Pri...   Product_5
# 1            1  {'ProductID': 'Product_10', 'Quantity': 2, 'Pr...  Product_10
# 2            1  {'ProductID': 'Product_5', 'Quantity': 3, 'Pri...   Product_5
# 3            1  {'ProductID': 'Product_7', 'Quantity': 1, 'Pri...   Product_7
# 4            1  {'ProductID': 'Product_3', 'Quantity': 2, 'Pri...   Product_3
# ...        ...                                                ...         ...
# 30020     9999  {'ProductID': 'Product_5', 'Quantity': 1, 'Pri...   Product_5
# 30021     9999  {'ProductID': 'Product_10', 'Quantity': 3, 'Pr...  Product_10
# 30022    10000  {'ProductID': 'Product_9', 'Quantity': 1, 'Pri...   Product_9
# 30023    10000  {'ProductID': 'Product_1', 'Quantity': 2, 'Pri...   Product_1
# 30024    10000  {'ProductID': 'Product_10', 'Quantity': 2, 'Pr...  Product_10
#
#        Quantity  Price
# 0             3  24.47
# 1             2  93.83
# 2             3  24.47
# 3             1  89.40
# 4             2  67.16
# ...         ...    ...
# 30020         1  24.47
# 30021         3  93.83
# 30022         1  13.71
# 30023         2  20.75
# 30024         2  93.83
#
# [30025 rows x 5 columns]

# %%
## We can access that above object as either a Python DF or SQL Object, wow, so cool!
import pandas.testing as pdt

# SQL
sql_pandas_df = con.execute("""SELECT * 
           FROM unpacked_products_df""").fetch_df()

# Python
pandas_df = unpacked_products_df.to_pandas()

# Test equality (using if not pdt.assert_frame_equal() because it returns None if equal)
if not pdt.assert_frame_equal(sql_pandas_df, pandas_df):
    print("Dataframes are equal!")
else:
    print("Dataframes are not equal!")
# Out:
# Dataframes are equal!

# %%
# Reorder columns
reordered_cols = con.execute("""SELECT Timestamp, TransactionID, UserID, SessionID,
                    ProductID, Quantity, Price,
                    TotalAmount, TaxAmount, ShippingAmount, Discounts, PaymentType,
                    ShippingAddress, BillingAddress, EventType
            FROM unpacked_products_df""").fetch_df()

reordered_cols
# Out:
#                  Timestamp  TransactionID  UserID  \
# 0      2022-09-28T00:00:00         487790   30595
# 1      2018-09-13T00:00:00        1757326   81849
# 2      2023-07-25T00:00:00        1431168   53327
# 3      2018-06-12T00:00:00        1929287   43428
# 4      2017-03-09T00:00:00        1740387   26638
# ...                    ...            ...     ...
# 19995  2023-05-06T00:00:00         317527   57089
# 19996  2019-09-09T00:00:00         254470   71364
# 19997  2022-06-10T00:00:00         235928   79122
# 19998  2016-03-17T00:00:00        1954290   75988
# 19999  2019-09-04T00:00:00        1514530   67030
#
#                                   SessionID   ProductID  Quantity  Price  \
# 0      5c782fd9-09ac-4206-aa48-260b4bb38d0c  Product_10         2  90.83
# 1      82ce3f80-af9d-41b0-8908-e626c4c080c2   Product_5         3  71.68
# 2      7ce47344-3ae1-4569-a2c8-99bcdd2c299f   Product_1         3  63.11
# 3      c2f9bcbf-4e95-4ff8-bbbb-f50e5855f950   Product_5         2  71.68
# 4      30210fed-8db6-42fb-b26a-d16c53e7070e   Product_2         3  32.78
# ...                                     ...         ...       ...    ...
# 19995  f9d2c574-aead-4ff5-bee6-5df353b08470   Product_3         3  29.12
# 19996  d871d3e4-350c-4e8a-839a-23421b374b14   Product_9         1  39.87
# 19997  78278801-3404-4a5a-a42c-b47af5ee983c   Product_3         2  29.12
# 19998  fb3a4560-35c1-456e-b960-3b5c134febee   Product_7         3  54.39
# 19999  c133b9a5-ac2f-4159-bfe8-d0c7b70552eb   Product_9         2  39.87
#
#        TotalAmount  TaxAmount  ShippingAmount  Discounts PaymentType  \
# 0           726.00      46.75           13.05       1.69  MasterCard
# 1           232.53      15.05            8.74       6.30  MasterCard
# 2           270.55      17.33           10.21       4.56  MasterCard
# 3           675.77      43.62           13.51       4.46  MasterCard
# 4           313.72      20.60            7.16       8.33      PayPal
# ...            ...        ...             ...        ...         ...
# 19995        97.77       6.12            6.82       2.53        Amex
# 19996       538.87      34.36           18.85       5.13      PayPal
# 19997       296.48      19.12            6.82       2.62      PayPal
# 19998       192.89      11.42           19.97       1.67      PayPal
# 19999       159.00       9.66           13.02       1.66        Visa
#
#                                          ShippingAddress  \
# 0      8636 Welch Canyon Apt. 709\nEast Alexhaven, DE...
# 1      4579 Victoria Forks Apt. 130\nNorth Manuelbury...
# 2                3892 Oconnell Way\nHaleyburgh, FM 63629
# 3           456 Hamilton Village\nEast Gabriel, IL 99482
# 4                    2207 King Neck\nWallhaven, OK 35530
# ...                                                  ...
# 19995        859 Lara Walk Apt. 936\nBowenstad, NV 08912
# 19996             830 Renee Common\nBrownmouth, CA 75939
# 19997            1546 Melvin Vista\nTurnerfort, AR 13781
# 19998     75287 Williamson Squares\nBrownmouth, FM 59979
# 19999  528 Johnson Forges Apt. 134\nNorth Helen, NJ 5...
#
#                                           BillingAddress            EventType
# 0              8155 Sydney Avenue\nAnthonyland, FM 40494  TransactionComplete
# 1      79757 Tracy Ports Apt. 612\nWest Edward, MD 67353  TransactionComplete
# 2      880 Craig Streets Suite 635\nWest Madeline, DC...  TransactionComplete
# 3      97811 Farley Track Suite 287\nJuliemouth, AK 2...  TransactionComplete
# 4              94189 Joel Dam\nEast Wesleystad, OK 60768  TransactionComplete
# ...                                                  ...                  ...
# 19995          0666 Amanda Crossroad\nHuntfurt, SC 40060  TransactionComplete
# 19996           61692 Aguilar Via\nCharlesberg, IA 49873  TransactionComplete
# 19997  711 Coleman Greens Apt. 656\nLake Christinaber...  TransactionComplete
# 19998  489 Tara Tunnel Apt. 735\nNorth Jacqueline, IL...  TransactionComplete
# 19999           884 Julia Landing\nSouth Larry, IA 40985  TransactionComplete
#
# [20000 rows x 15 columns]

# %%
# First col I notice is a timestamp and we want to turn that to an appropriate datetime value
# reordered_cols
correct_time = con.execute("""SELECT strptime(Timestamp, '%Y-%m-%dT%H:%M:%S') AS Timestamp, *
                              FROM reordered_cols""").fetch_df()
correct_time
# SQL doesn't have a DROP column function, so we'll just select the columns we want when we are ready
# Out:
#        Timestamp          Timestamp_2  TransactionID  UserID  \
# 0     2022-09-28  2022-09-28T00:00:00         487790   30595
# 1     2018-09-13  2018-09-13T00:00:00        1757326   81849
# 2     2023-07-25  2023-07-25T00:00:00        1431168   53327
# 3     2018-06-12  2018-06-12T00:00:00        1929287   43428
# 4     2017-03-09  2017-03-09T00:00:00        1740387   26638
# ...          ...                  ...            ...     ...
# 19995 2023-05-06  2023-05-06T00:00:00         317527   57089
# 19996 2019-09-09  2019-09-09T00:00:00         254470   71364
# 19997 2022-06-10  2022-06-10T00:00:00         235928   79122
# 19998 2016-03-17  2016-03-17T00:00:00        1954290   75988
# 19999 2019-09-04  2019-09-04T00:00:00        1514530   67030
#
#                                   SessionID   ProductID  Quantity  Price  \
# 0      5c782fd9-09ac-4206-aa48-260b4bb38d0c  Product_10         2  90.83
# 1      82ce3f80-af9d-41b0-8908-e626c4c080c2   Product_5         3  71.68
# 2      7ce47344-3ae1-4569-a2c8-99bcdd2c299f   Product_1         3  63.11
# 3      c2f9bcbf-4e95-4ff8-bbbb-f50e5855f950   Product_5         2  71.68
# 4      30210fed-8db6-42fb-b26a-d16c53e7070e   Product_2         3  32.78
# ...                                     ...         ...       ...    ...
# 19995  f9d2c574-aead-4ff5-bee6-5df353b08470   Product_3         3  29.12
# 19996  d871d3e4-350c-4e8a-839a-23421b374b14   Product_9         1  39.87
# 19997  78278801-3404-4a5a-a42c-b47af5ee983c   Product_3         2  29.12
# 19998  fb3a4560-35c1-456e-b960-3b5c134febee   Product_7         3  54.39
# 19999  c133b9a5-ac2f-4159-bfe8-d0c7b70552eb   Product_9         2  39.87
#
#        TotalAmount  TaxAmount  ShippingAmount  Discounts PaymentType  \
# 0           726.00      46.75           13.05       1.69  MasterCard
# 1           232.53      15.05            8.74       6.30  MasterCard
# 2           270.55      17.33           10.21       4.56  MasterCard
# 3           675.77      43.62           13.51       4.46  MasterCard
# 4           313.72      20.60            7.16       8.33      PayPal
# ...            ...        ...             ...        ...         ...
# 19995        97.77       6.12            6.82       2.53        Amex
# 19996       538.87      34.36           18.85       5.13      PayPal
# 19997       296.48      19.12            6.82       2.62      PayPal
# 19998       192.89      11.42           19.97       1.67      PayPal
# 19999       159.00       9.66           13.02       1.66        Visa
#
#                                          ShippingAddress  \
# 0      8636 Welch Canyon Apt. 709\nEast Alexhaven, DE...
# 1      4579 Victoria Forks Apt. 130\nNorth Manuelbury...
# 2                3892 Oconnell Way\nHaleyburgh, FM 63629
# 3           456 Hamilton Village\nEast Gabriel, IL 99482
# 4                    2207 King Neck\nWallhaven, OK 35530
# ...                                                  ...
# 19995        859 Lara Walk Apt. 936\nBowenstad, NV 08912
# 19996             830 Renee Common\nBrownmouth, CA 75939
# 19997            1546 Melvin Vista\nTurnerfort, AR 13781
# 19998     75287 Williamson Squares\nBrownmouth, FM 59979
# 19999  528 Johnson Forges Apt. 134\nNorth Helen, NJ 5...
#
#                                           BillingAddress            EventType
# 0              8155 Sydney Avenue\nAnthonyland, FM 40494  TransactionComplete
# 1      79757 Tracy Ports Apt. 612\nWest Edward, MD 67353  TransactionComplete
# 2      880 Craig Streets Suite 635\nWest Madeline, DC...  TransactionComplete
# 3      97811 Farley Track Suite 287\nJuliemouth, AK 2...  TransactionComplete
# 4              94189 Joel Dam\nEast Wesleystad, OK 60768  TransactionComplete
# ...                                                  ...                  ...
# 19995          0666 Amanda Crossroad\nHuntfurt, SC 40060  TransactionComplete
# 19996           61692 Aguilar Via\nCharlesberg, IA 49873  TransactionComplete
# 19997  711 Coleman Greens Apt. 656\nLake Christinaber...  TransactionComplete
# 19998  489 Tara Tunnel Apt. 735\nNorth Jacqueline, IL...  TransactionComplete
# 19999           884 Julia Landing\nSouth Larry, IA 40985  TransactionComplete
#
# [20000 rows x 16 columns]

# %%
# Next up I see the string column ProductID, which we want to turn into an INT by parsing all digits after the _
correct_product_id = con.execute("""SELECT *,
                                    CAST(
                                        list_extract(
                                            regexp_split_to_array(ProductID, '_'),
                                            2) 
                                    AS INT) AS ProductID_int
            FROM correct_time""").fetch_df()
correct_product_id
# Out:
#    Timestamp          Timestamp_2  TransactionID  UserID  \
# 0 2022-09-28  2022-09-28T00:00:00         487790   30595
# 1 2018-09-13  2018-09-13T00:00:00        1757326   81849
# 2 2023-07-25  2023-07-25T00:00:00        1431168   53327
# 3 2018-06-12  2018-06-12T00:00:00        1929287   43428
# 4 2017-03-09  2017-03-09T00:00:00        1740387   26638
# 5 2020-05-04  2020-05-04T00:00:00         523702   14262
# 6 2020-05-31  2020-05-31T00:00:00        1645982   19843
# 7 2021-03-15  2021-03-15T00:00:00        1121250   44025
# 8 2021-01-06  2021-01-06T00:00:00         675913   42070
# 9 2022-03-21  2022-03-21T00:00:00         355907   50793
#
#                               SessionID   ProductID  Quantity  Price  \
# 0  5c782fd9-09ac-4206-aa48-260b4bb38d0c  Product_10         2  90.83
# 1  82ce3f80-af9d-41b0-8908-e626c4c080c2   Product_5         3  71.68
# 2  7ce47344-3ae1-4569-a2c8-99bcdd2c299f   Product_1         3  63.11
# 3  c2f9bcbf-4e95-4ff8-bbbb-f50e5855f950   Product_5         2  71.68
# 4  30210fed-8db6-42fb-b26a-d16c53e7070e   Product_2         3  32.78
# 5  d7f3c27d-430c-4842-a426-d53ac40e1505   Product_8         3  48.42
# 6  4abfd01d-2e94-441b-83ed-6cf806043456   Product_8         2  48.42
# 7  229eb9aa-5fec-459b-9019-037fdec1b39a   Product_2         3  32.78
# 8  1183921b-0f33-4e7f-9b63-856c61f131e4   Product_8         2  48.42
# 9  4fdbf60c-46e8-486d-a8d7-f0b25729dc39   Product_8         2  48.42
#
#    TotalAmount  TaxAmount  ShippingAmount  Discounts PaymentType  \
# 0       726.00      46.75           13.05       1.69  MasterCard
# 1       232.53      15.05            8.74       6.30  MasterCard
# 2       270.55      17.33           10.21       4.56  MasterCard
# 3       675.77      43.62           13.51       4.46  MasterCard
# 4       313.72      20.60            7.16       8.33      PayPal
# 5       157.64      10.17           11.22       9.01        Visa
# 6       345.40      22.80            6.74       9.79        Visa
# 7       149.39       9.18           16.72       7.63        Amex
# 8       107.14       6.78           11.13       7.61        Amex
# 9       312.49      19.92           17.29       9.23        Amex
#
#                                      ShippingAddress  \
# 0  8636 Welch Canyon Apt. 709\nEast Alexhaven, DE...
# 1  4579 Victoria Forks Apt. 130\nNorth Manuelbury...
# 2            3892 Oconnell Way\nHaleyburgh, FM 63629
# 3       456 Hamilton Village\nEast Gabriel, IL 99482
# 4                2207 King Neck\nWallhaven, OK 35530
# 5             81198 Gary Place\nPort Betty, SC 70878
# 6  71970 Smith Road Suite 015\nKevinborough, KY 0...
# 7        74737 Knight Landing\nJosephshire, WV 68312
# 8          775 Kristin Flats\nSouth Connie, MD 44507
# 9  2078 Susan Knolls Apt. 884\nPort Colleen, AR 1...
#
#                                       BillingAddress            EventType  \
# 0          8155 Sydney Avenue\nAnthonyland, FM 40494  TransactionComplete
# 1  79757 Tracy Ports Apt. 612\nWest Edward, MD 67353  TransactionComplete
# 2  880 Craig Streets Suite 635\nWest Madeline, DC...  TransactionComplete
# 3  97811 Farley Track Suite 287\nJuliemouth, AK 2...  TransactionComplete
# 4          94189 Joel Dam\nEast Wesleystad, OK 60768  TransactionComplete
# 5  0293 Jennifer Turnpike Suite 783\nPatriciaches...  TransactionComplete
# 6  83783 Thomas Drives Apt. 136\nEast Stephanie, ...  TransactionComplete
# 7           72247 Johnson Ports\nNew Donna, CO 68724  TransactionComplete
# 8          603 Chapman View\nSouth Crystal, CO 35151  TransactionComplete
# 9  062 Sanders Islands Apt. 565\nMichelleside, PW...  TransactionComplete
#
#    ProductID_int
# 0             10
# 1              5
# 2              1
# 3              5
# 4              2
# 5              8
# 6              8
# 7              2
# 8              8
# 9              8

# %% [markdown]
# ## We've done a lot of the cleaning we want to do, now let's think more about our data model
#
# - We have again the Product ID which in this circumstance doesn't have much information about the products available.
# - But in the real world we would have a product catalog.
# - That would provide us context to what products we are selling, and a Data Scientist might need to easier get that information back.
# - We are going to create another table called `DIM_PRODUCTS` which would represent that product catalog.

# %%
con.execute("""
            -- Creating it in the staging schema to be available to our data model
            CREATE SCHEMA IF NOT EXISTS staging;
            
            -- Creating table dim_products
            CREATE TABLE IF NOT EXISTS staging.dim_products AS
            SELECT DISTINCT(ProductID_int) AS Product_ID,
                       'Comment about product' AS Product_Info
                FROM correct_product_id""").fetch_df()


con.execute("""SELECT * FROM staging.dim_products""").fetch_df()
# Out:
#    Product_ID           Product_Info
# 0           5  Comment about product
# 1           8  Comment about product
# 2          10  Comment about product
# 3           1  Comment about product
# 4           2  Comment about product

# %%
# Since we are following the same process for PaymentType and EventType, let's create a function to do this, but they don't have unique IDs so we add in UUID

def create_dim_table(table_name, col_name):
    """
    Create a dim table with a unique ID and a comment column
    Assuming the attribute we are creating an ID for is not already an ID.
    
    Example: We have Mastercard, Visa, etc for Payment Types, but there's no Payment Type Code yet
    We will create that payment type code
    
    But, for PRODUCTs, they're integers, so we don't need to recreate a different ID for those products
    
    Args:
        table_name (str): Name of table to create
        col_name (str): Name of column to create
    """
    con.execute(f"""
                -- Creating it in the staging schema to be available to our data model
                CREATE SCHEMA IF NOT EXISTS staging;
                
                -- Creating table dim_{table_name}
                CREATE TABLE IF NOT EXISTS staging.{table_name} (
                    id INT NOT NULL UNIQUE,
                    {col_name} VARCHAR,
                    {col_name}_Info VARCHAR
                );
                
                INSERT OR REPLACE INTO staging.{table_name}
                WITH base_table AS (
                            SELECT DISTINCT({col_name}) AS {col_name},
                                'Comment about {col_name}' AS {col_name}_Info
                    FROM correct_product_id
                    )
                    
                SELECT ROW_NUMBER() OVER () as id,
                        {col_name},
                        {col_name}_Info
                FROM base_table""")
 
# Payment Type   
con.execute("""DROP TABLE IF EXISTS staging.dim_payment_type""")
create_dim_table('dim_payment_type', 'PaymentType')
#con.execute("""SELECT * FROM staging.dim_payment_type""").fetch_df()

# Event Type
con.execute("""DROP TABLE IF EXISTS staging.dim_event_type""")
create_dim_table('dim_event_type', 'EventType')
con.execute("""SELECT * FROM staging.dim_event_type""").fetch_df()
# Out:
#    id            EventType           EventType_Info
# 0   1  TransactionComplete  Comment about EventType

# %%
# Dispaly Table Info
con.execute("""SHOW ALL TABLES""").fetch_df()
# Out:
#   database   schema                           name  \
# 0   duckdb  landing                   transactions
# 1   duckdb     main                          items
# 2   duckdb     main                   transactions
# 3   duckdb     main                  transactions2
# 4   duckdb  staging                 dim_event_type
# 5   duckdb  staging               dim_payment_type
# 6   duckdb  staging                   dim_products
# 7   duckdb  staging               fct_transactions
# 8   duckdb  staging  sample_fct_transaction_detail
# 9   duckdb  staging        sample_fct_transactions
#
#                                         column_names  \
# 0  [EventType, Timestamp, TransactionID, UserID, ...
# 1  [EventType, Timestamp, TransactionID, UserID, ...
# 2  [EventType, Timestamp, TransactionID, UserID, ...
# 3  [EventType, Timestamp, TransactionID, UserID, ...
# 4                    [id, EventType, EventType_Info]
# 5                [id, PaymentType, PaymentType_Info]
# 6                         [Product_ID, Product_Info]
# 7  [Timestamp, TransactionID, UserID, SessionID, ...
# 8    [TransactionID, ProductID, Quantity, UnitPrice]
# 9  [Timestamp, TransactionID, UserID, SessionID, ...
#
#                                         column_types  temporary
# 0  [VARCHAR, VARCHAR, BIGINT, BIGINT, UUID, DOUBL...      False
# 1  [VARCHAR, TIMESTAMP, INTEGER, INTEGER, VARCHAR...      False
# 2  [VARCHAR, VARCHAR, BIGINT, BIGINT, UUID, DOUBL...      False
# 3  [VARCHAR, VARCHAR, BIGINT, BIGINT, UUID, DOUBL...      False
# 4                        [INTEGER, VARCHAR, VARCHAR]      False
# 5                        [INTEGER, VARCHAR, VARCHAR]      False
# 6                                 [INTEGER, VARCHAR]      False
# 7  [TIMESTAMP, BIGINT, BIGINT, VARCHAR, DOUBLE, D...      False
# 8                 [BIGINT, INTEGER, INTEGER, DOUBLE]      False
# 9  [TIMESTAMP, BIGINT, BIGINT, VARCHAR, DOUBLE, D...      False

# %%
# We have some tables that came from my dev, let's show another way to filter out table names we might not want
# https://duckdb.org/docs/archive/0.9.2/sql/information_schema
con.execute("""
            SELECT *
            FROM information_schema.tables
            WHERE table_schema IN ('landing', 'staging')
            AND table_name NOT IN ('sample_fct_transaction_detail', 'sample_fct_transactions')""").fetch_df()
# Out:
#   table_catalog table_schema        table_name  table_type  \
# 0        duckdb      landing      transactions  BASE TABLE
# 1        duckdb      staging    dim_event_type  BASE TABLE
# 2        duckdb      staging  dim_payment_type  BASE TABLE
# 3        duckdb      staging  fct_transactions  BASE TABLE
# 4        duckdb      staging      dim_products  BASE TABLE
#
#    self_referencing_column_name  reference_generation  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
#
#    user_defined_type_catalog  user_defined_type_schema  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#    user_defined_type_name is_insertable_into is_typed commit_action
# 0                     NaN                YES       NO          None
# 1                     NaN                YES       NO          None
# 2                     NaN                YES       NO          None
# 3                     NaN                YES       NO          None
# 4                     NaN                YES       NO          None

# %% [markdown]
# ## Back to our Main Table

# %%
correct_product_id
# Out:
#    Timestamp          Timestamp_2  TransactionID  UserID  \
# 0 2022-09-28  2022-09-28T00:00:00         487790   30595
# 1 2018-09-13  2018-09-13T00:00:00        1757326   81849
# 2 2023-07-25  2023-07-25T00:00:00        1431168   53327
# 3 2018-06-12  2018-06-12T00:00:00        1929287   43428
# 4 2017-03-09  2017-03-09T00:00:00        1740387   26638
# 5 2020-05-04  2020-05-04T00:00:00         523702   14262
# 6 2020-05-31  2020-05-31T00:00:00        1645982   19843
# 7 2021-03-15  2021-03-15T00:00:00        1121250   44025
# 8 2021-01-06  2021-01-06T00:00:00         675913   42070
# 9 2022-03-21  2022-03-21T00:00:00         355907   50793
#
#                               SessionID   ProductID  Quantity  Price  \
# 0  5c782fd9-09ac-4206-aa48-260b4bb38d0c  Product_10         2  90.83
# 1  82ce3f80-af9d-41b0-8908-e626c4c080c2   Product_5         3  71.68
# 2  7ce47344-3ae1-4569-a2c8-99bcdd2c299f   Product_1         3  63.11
# 3  c2f9bcbf-4e95-4ff8-bbbb-f50e5855f950   Product_5         2  71.68
# 4  30210fed-8db6-42fb-b26a-d16c53e7070e   Product_2         3  32.78
# 5  d7f3c27d-430c-4842-a426-d53ac40e1505   Product_8         3  48.42
# 6  4abfd01d-2e94-441b-83ed-6cf806043456   Product_8         2  48.42
# 7  229eb9aa-5fec-459b-9019-037fdec1b39a   Product_2         3  32.78
# 8  1183921b-0f33-4e7f-9b63-856c61f131e4   Product_8         2  48.42
# 9  4fdbf60c-46e8-486d-a8d7-f0b25729dc39   Product_8         2  48.42
#
#    TotalAmount  TaxAmount  ShippingAmount  Discounts PaymentType  \
# 0       726.00      46.75           13.05       1.69  MasterCard
# 1       232.53      15.05            8.74       6.30  MasterCard
# 2       270.55      17.33           10.21       4.56  MasterCard
# 3       675.77      43.62           13.51       4.46  MasterCard
# 4       313.72      20.60            7.16       8.33      PayPal
# 5       157.64      10.17           11.22       9.01        Visa
# 6       345.40      22.80            6.74       9.79        Visa
# 7       149.39       9.18           16.72       7.63        Amex
# 8       107.14       6.78           11.13       7.61        Amex
# 9       312.49      19.92           17.29       9.23        Amex
#
#                                      ShippingAddress  \
# 0  8636 Welch Canyon Apt. 709\nEast Alexhaven, DE...
# 1  4579 Victoria Forks Apt. 130\nNorth Manuelbury...
# 2            3892 Oconnell Way\nHaleyburgh, FM 63629
# 3       456 Hamilton Village\nEast Gabriel, IL 99482
# 4                2207 King Neck\nWallhaven, OK 35530
# 5             81198 Gary Place\nPort Betty, SC 70878
# 6  71970 Smith Road Suite 015\nKevinborough, KY 0...
# 7        74737 Knight Landing\nJosephshire, WV 68312
# 8          775 Kristin Flats\nSouth Connie, MD 44507
# 9  2078 Susan Knolls Apt. 884\nPort Colleen, AR 1...
#
#                                       BillingAddress            EventType  \
# 0          8155 Sydney Avenue\nAnthonyland, FM 40494  TransactionComplete
# 1  79757 Tracy Ports Apt. 612\nWest Edward, MD 67353  TransactionComplete
# 2  880 Craig Streets Suite 635\nWest Madeline, DC...  TransactionComplete
# 3  97811 Farley Track Suite 287\nJuliemouth, AK 2...  TransactionComplete
# 4          94189 Joel Dam\nEast Wesleystad, OK 60768  TransactionComplete
# 5  0293 Jennifer Turnpike Suite 783\nPatriciaches...  TransactionComplete
# 6  83783 Thomas Drives Apt. 136\nEast Stephanie, ...  TransactionComplete
# 7           72247 Johnson Ports\nNew Donna, CO 68724  TransactionComplete
# 8          603 Chapman View\nSouth Crystal, CO 35151  TransactionComplete
# 9  062 Sanders Islands Apt. 565\nMichelleside, PW...  TransactionComplete
#
#    ProductID_int
# 0             10
# 1              5
# 2              1
# 3              5
# 4              2
# 5              8
# 6              8
# 7              2
# 8              8
# 9              8

# %% [markdown]
# ## Caveat about our table: We have traits that pertain to the Line Items themselves (Product ID, QTY, and Price), and then other pieces that pertain to the Order itself (Discounts, Total Price, Billing Address, Shipping Address)
#
# ### So, we will split our table now into 2 different tables.

# %%
transactions_filtered_out_detail = con.execute("""
            -- Creating our FCT_TRANSACTIONS table
            WITH unique_transactions AS (
               SELECT TransactionID, ROW_NUMBER() over (PARTITION BY TransactionID) AS row_number
               FROM correct_product_id
            ),
            
            final_table AS (
            SELECT Timestamp,
                   transactions1.TransactionID,
                   UserID,
                   SessionID,
                   TotalAmount,
                   TaxAmount,
                   ShippingAmount,
                   Discounts,
                   PaymentType,
                   ShippingAddress,
                   BillingAddress,
                   EventType
                FROM correct_product_id transactions1
                INNER JOIN unique_transactions transactions2
                  ON transactions1.TransactionID = transactions2.TransactionID
               WHERE transactions2.row_number = 1
               )
               
             SELECT *
             FROM final_table""").fetch_df()


# Step 2: Create the staging.sample_fct_transactions table using the data from the DataFrame
con.execute("""
            DROP TABLE staging.sample_fct_transactions
            """)

con.execute("""
            CREATE TABLE IF NOT EXISTS staging.sample_fct_transactions AS
            SELECT *
            FROM transactions_filtered_out_detail""")

# %%
# Finish out adding codes to the transaction table, and we've got our staging table!
# (we've left address alone for now, this could be a good exercise to do on your own)
final_staging_transactions = con.execute("""
            with final_staging_transactions AS (
            SELECT fct_trans.Timestamp,
                fct_trans.TransactionID,
                fct_trans.UserID,
                fct_trans.SessionID,
                fct_trans.TotalAmount,
                fct_trans.TaxAmount,
                fct_trans.ShippingAmount,
                fct_trans.Discounts,
                fct_trans.ShippingAddress,
                fct_trans.BillingAddress,
                dim_payment_type.id AS PaymentTypeCode,
                dim_event_type.id AS EventTypeCode
            FROM staging.sample_fct_transactions fct_trans
            INNER JOIN staging.dim_payment_type
              ON fct_trans.PaymentType = staging.dim_payment_type.PaymentType
            INNER JOIN staging.dim_event_type
                ON fct_trans.EventType = staging.dim_event_type.EventType
            )
            
            SELECT *
            FROM final_staging_transactions""").fetch_df()

# Step 2: Create the staging.fct_transactions table using the data from the DataFrame
con.execute("""
            DROP TABLE IF EXISTS staging.fct_transactions
            """)
            
con.execute("""
            CREATE TABLE IF NOT EXISTS staging.fct_transactions AS
            SELECT *
            FROM final_staging_transactions""")

# %% [markdown]
# ### Transaction Detail Table Creation

# %%
# Creating the transaction detail table
transaction_detail = con.execute("""
            -- Creating our FCT_TRANSACTIONS table
            WITH unique_transaction_products AS (
               SELECT TransactionID, ProductID_int, ROW_NUMBER() over (PARTITION BY TransactionID, ProductID) AS row_number
               FROM correct_product_id
            ),
            
            final_table AS (
            SELECT transactions1.TransactionID,
                     transactions1.ProductID_int AS ProductID,
                     Quantity,
                     Price AS UnitPrice
                FROM correct_product_id transactions1
                INNER JOIN unique_transaction_products transactions2
                  ON transactions1.TransactionID = transactions2.TransactionID
                  AND transactions1.ProductID_int = transactions2.ProductID_int
               WHERE transactions2.row_number = 1
               )
               
               SELECT *
               FROM final_table""").fetch_df()

# Step 2: Create the staging.sample_fct_transactions table using the data from the DataFrame
con.execute("""
            DROP TABLE IF EXISTS staging.fct_transaction_detail
            """)

con.execute("""
            CREATE TABLE IF NOT EXISTS staging.fct_transaction_detail AS
            SELECT *
            FROM transaction_detail""")

# %% [markdown]
# ### Evaluate what tables we have in our environment

# %%
con.execute("""SHOW ALL TABLES;""").fetch_df()
# Out:
#    database   schema                           name  \
# 0    duckdb  landing                   transactions
# 1    duckdb     main                          items
# 2    duckdb     main                   transactions
# 3    duckdb     main                  transactions2
# 4    duckdb  staging                 dim_event_type
# 5    duckdb  staging               dim_payment_type
# 6    duckdb  staging                   dim_products
# 7    duckdb  staging         fct_transaction_detail
# 8    duckdb  staging               fct_transactions
# 9    duckdb  staging  sample_fct_transaction_detail
# 10   duckdb  staging        sample_fct_transactions
#
#                                          column_names  \
# 0   [EventType, Timestamp, TransactionID, UserID, ...
# 1   [EventType, Timestamp, TransactionID, UserID, ...
# 2   [EventType, Timestamp, TransactionID, UserID, ...
# 3   [EventType, Timestamp, TransactionID, UserID, ...
# 4                     [id, EventType, EventType_Info]
# 5                 [id, PaymentType, PaymentType_Info]
# 6                          [Product_ID, Product_Info]
# 7     [TransactionID, ProductID, Quantity, UnitPrice]
# 8   [Timestamp, TransactionID, UserID, SessionID, ...
# 9     [TransactionID, ProductID, Quantity, UnitPrice]
# 10  [Timestamp, TransactionID, UserID, SessionID, ...
#
#                                          column_types  temporary
# 0   [VARCHAR, VARCHAR, BIGINT, BIGINT, UUID, DOUBL...      False
# 1   [VARCHAR, TIMESTAMP, INTEGER, INTEGER, VARCHAR...      False
# 2   [VARCHAR, VARCHAR, BIGINT, BIGINT, UUID, DOUBL...      False
# 3   [VARCHAR, VARCHAR, BIGINT, BIGINT, UUID, DOUBL...      False
# 4                         [INTEGER, VARCHAR, VARCHAR]      False
# 5                         [INTEGER, VARCHAR, VARCHAR]      False
# 6                                  [INTEGER, VARCHAR]      False
# 7                  [BIGINT, INTEGER, INTEGER, DOUBLE]      False
# 8   [TIMESTAMP, BIGINT, BIGINT, VARCHAR, DOUBLE, D...      False
# 9                  [BIGINT, INTEGER, INTEGER, DOUBLE]      False
# 10  [TIMESTAMP, BIGINT, BIGINT, VARCHAR, DOUBLE, D...      False

# %%
# We have some tables that came from my dev, let's show another way to filter out table names we might not want
# https://duckdb.org/docs/archive/0.9.2/sql/information_schema
con.execute("""
            SELECT *
            FROM information_schema.tables
            WHERE table_schema IN ('landing', 'staging')
            AND table_name NOT IN ('sample_fct_transaction_detail', 'sample_fct_transactions')""").fetch_df()
# Out:
#   table_catalog table_schema              table_name  table_type  \
# 0        duckdb      landing            transactions  BASE TABLE
# 1        duckdb      staging  fct_transaction_detail  BASE TABLE
# 2        duckdb      staging          dim_event_type  BASE TABLE
# 3        duckdb      staging        dim_payment_type  BASE TABLE
# 4        duckdb      staging        fct_transactions  BASE TABLE
# 5        duckdb      staging            dim_products  BASE TABLE
#
#    self_referencing_column_name  reference_generation  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# 5                           NaN                   NaN
#
#    user_defined_type_catalog  user_defined_type_schema  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# 5                        NaN                       NaN
#
#    user_defined_type_name is_insertable_into is_typed commit_action
# 0                     NaN                YES       NO          None
# 1                     NaN                YES       NO          None
# 2                     NaN                YES       NO          None
# 3                     NaN                YES       NO          None
# 4                     NaN                YES       NO          None
# 5                     NaN                YES       NO          None
